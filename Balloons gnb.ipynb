# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
balon = pd.read_csv('balloons.csv')
balon.head()
# Out:
#     color   size      act    age inflated
# 0  YELLOW  SMALL  STRETCH  ADULT        T
# 1  YELLOW  SMALL  STRETCH  CHILD        T
# 2  YELLOW  SMALL      DIP  ADULT        T
# 3  YELLOW  SMALL      DIP  CHILD        F
# 4  YELLOW  SMALL      DIP  CHILD        F

# %%
balon.rename(columns={'%color':'color'})
for col in ["color", 'size', 'act', 'age']:
    balon[col] = balon[col].astype('category')
balon.dtypes
# Out:
# color       category
# size        category
# act         category
# age         category
# inflated      object
# dtype: object

# %%
for col in ["color", 'size', 'act', 'age']:
    balon[col] = balon[col].cat.codes
balon.head(21)
# Out:
#     color  size  act  age inflated
# 0       1     1    1    0        T
# 1       1     1    1    1        T
# 2       1     1    0    0        T
# 3       1     1    0    1        F
# 4       1     1    0    1        F
# 5       1     0    1    0        T
# 6       1     0    1    1        T
# 7       1     0    0    0        T
# 8       1     0    0    1        F
# 9       1     0    0    1        F
# 10      0     1    1    0        T
# 11      0     1    1    1        T
# 12      0     1    0    0        T
# 13      0     1    0    1        F
# 14      0     1    0    1        F
# 15      0     0    1    0        T
# 16      0     0    1    1        T
# 17      0     0    0    0        T
# 18      0     0    0    1        F
# 19      0     0    0    1        F
# 20      1     1    1    0        T

# %%
x = balon.drop(['inflated'], axis = 1)
y = balon['inflated']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 123)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
y_pred = gnb.predict(x_test)
y_pred
# Out:
# array(['F', 'T', 'F', 'F', 'T', 'T', 'F', 'T', 'F', 'F', 'F', 'F', 'T',
#        'F', 'F', 'F', 'F', 'F', 'F'], dtype='<U1')

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[12,  1],
#        [ 2,  4]])

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Overerall :",classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.8421052631578947
# Overerall :               precision    recall  f1-score   support
#
#            F       0.86      0.92      0.89        13
#            T       0.80      0.67      0.73         6
#
#     accuracy                           0.84        19
#    macro avg       0.83      0.79      0.81        19
# weighted avg       0.84      0.84      0.84        19
